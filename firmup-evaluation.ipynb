# %%
import rich.pretty

rich.pretty.install()

# %%
import msgspec
import pandas as pd
import seaborn as sns
import matplotlib as mpl
from matplotlib import pyplot as plt
import sqlalchemy as sa
import networkx as nx
import sklearn.metrics
from sklearn.metrics import roc_curve
from evaluatie.neighbsim.neighbsim import neighbsim, NeighBSimArgs
import itertools
from tqdm import tqdm
import scipy
import scipy.stats
import numpy as np

# %%
from evaluatie import models as m
from evaluatie.data import Dataset, Pair, DatasetSpec, similarity_graph_from_pair

# %%
from evaluatie.firmup.firmup import firmup, FirmUPArgs

# %%
tqdm.pandas()

# %%
xo_df = pd.read_csv("datasets/call-graph:xo.csv")
xo_df = xo_df.iloc[:1000]

xaxb_df = pd.read_csv("datasets/call-graph:xaxb.csv")
xaxb_df = xaxb_df.iloc[:1000]

xo_o0xo3_df = pd.read_csv("datasets/call-graph:xo:o0xo3.csv")
xo_o0xo3_df = xo_o0xo3_df.iloc[:1000]

xo_o2xo3_df = pd.read_csv("datasets/call-graph:xo:o2xo3.csv")
xo_o2xo3_df = xo_o2xo3_df.iloc[:1000]

# %%
qb_id = 19413
tb_id = 20043

qf_id = 12595642

sg = similarity_graph_from_pair(qb_id, tb_id)

args = FirmUPArgs(
    similarity_graph=sg,
    query_binary_id=qb_id,
    target_binary_id=tb_id,
)
firmup(qf_id, args)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 13
#       6 sg = similarity_graph_from_pair(qb_id, tb_id)
#       8 args = FirmUPArgs(
#       9     similarity_graph=sg,
#      10     query_binary_id=qb_id,
#      11     target_binary_id=tb_id,
#      12 )
# ---> 13 firmup(qf_id, args)
#
# File ~/workspace/sources/~maringuu/|master-thesis/evaluatie/evaluatie/firmup/firmup.py:38, in firmup(query_function_id, args)
#      31 other_binary_id = args.query_binary_id if my_binary_id == args.target_binary_id else args.target_binary_id
#      33 unmatched_sg = sg.subgraph(
#      34     # Restrict to all unmatched nodes
#      35     [node for node in sg.nodes if node not in matching]
#      36 )
# ---> 38 forward_match = _get_best_match(
#      39     my_function_id,
#      40     similarity_graph=unmatched_sg,
#      41 )
#      43 backward_match = _get_best_match(
#      44     forward_match,
#      45     similarity_graph=unmatched_sg,
#      46 )
#      48 my_stack_entry = (my_binary_id, my_function_id)
#
# File ~/workspace/sources/~maringuu/|master-thesis/evaluatie/evaluatie/firmup/firmup.py:73, in _get_best_match(function_id, similarity_graph)
#      72 def _get_best_match(function_id: int, similarity_graph: nx.Graph):
# ---> 73     return max(
#      74         similarity_graph[function_id],
#      75         key=lambda other_id: similarity_graph.get_edge_data(function_id, other_id)["weight"],
#      76     )
#
# TypeError: '>' not supported between instances of 'NoneType' and 'NoneType'

# %%
sg[qf_id]
# Out:
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# AtlasView({12934122: {'weight': None}, 12934131: {'weight': None}, 12934137: {'weight': None}, 12934148: {'weight': None}, 12934155: {'weight': None}, 12934160: {'weight': None}, 12934166: {'weight': None}, 12934174: {'weight': None}, 12934180: {'weight': None}, 12934188: {'weight': None}, 12934194: {'weight': None}, 12934201: {'weight': None}, 12934208: {'weight': None}, 12934216: {'weight': None}, 12934225: {'weight': None}, 12934232: {'weight': None}, 12934237: {'weight': None}, 12934245: {'weight': None}, 12934254: {'weight': None}, 12934263: {'weight': None},